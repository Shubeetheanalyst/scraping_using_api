# %% [markdown]
# # Movies_api

# %%
import pandas as pd
import requests
from tqdm import tqdm

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
temp_data = pd.DataFrame(response.json()['results'])[['id','original_title','release_date','overview','popularity','vote_average','vote_count']]

# %%
temp_data.head()

# %%
df = pd.DataFrame()

# %%
df

# %%
for i in range (1, 548):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_data = pd.DataFrame(response.json()['results'])[['id','original_title','release_date','overview','popularity','vote_average','vote_count']]
    df = df.append(temp_data,ignore_index=True)

# %%
for i in tqdm(range(1, 548)):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_data = pd.DataFrame(response.json()['results'])[['id','original_title','release_date','overview','popularity','vote_average','vote_count']]
    df = df.append(temp_data, ignore_index=True)

print("Data extraction complete.")

# %%
df.to_csv('movies.csv', index = False)

# %% [markdown]
# # Products

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://dummyjson.com/products')

# %%
response
# Out:
# <Response [200]>

# %%
pd.DataFrame(response.json()['products'])[['id','title','description','price','discountPercentage','rating','stock','brand']]
# Out:
#     id                                   title  \
# 0    1                                iPhone 9
# 1    2                                iPhone X
# 2    3                      Samsung Universe 9
# 3    4                                 OPPOF19
# 4    5                              Huawei P30
# 5    6                             MacBook Pro
# 6    7                     Samsung Galaxy Book
# 7    8              Microsoft Surface Laptop 4
# 8    9                          Infinix INBOOK
# 9   10                 HP Pavilion 15-DK1056WM
# 10  11                             perfume Oil
# 11  12                           Brown Perfume
# 12  13              Fog Scent Xpressio Perfume
# 13  14  Non-Alcoholic Concentrated Perfume Oil
# 14  15                    Eau De Perfume Spray
# 15  16                   Hyaluronic Acid Serum
# 16  17                           Tree Oil 30ml
# 17  18              Oil Free Moisturizer 100ml
# 18  19                      Skin Beauty Serum.
# ...

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,101):
    response = requests.get('https://dummyjson.com/products')
    temp_data = pd.DataFrame(response.json()['products'])[['id','title','description','price','discountPercentage','rating','stock','brand']]
    df = df.append(temp_data,ignore_index = True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_23964\1013199701.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data,ignore_index = True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_23964\1013199701.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data,ignore_index = True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_23964\1013199701.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data,ignore_index = True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_23964\1013199701.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data,ignore_index = True)
# ...

# %%
df.to_csv('smartphones.csv',index=False)

# %% [markdown]
# # Properties

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://cloudapi.jagahonline.com/api/featured_projects')
response
# Out:
# <Response [200]>

# %%
temp_data = pd.DataFrame(response.json()['data'])[['id','title','builder_id','description','country_id','price_txt']]

# %%
temp_data
# Out:
#    id                      title  builder_id  \
# 0   8      Index Industrial Park           3
# 1   7   Kings Scenic Mall Sukkur           1
# 2   6   Qaswaa Residency Phase 3           2
# 3   5  Kings Paradise Apartments           1
# 4   4              Kings Regency           1
# 5   3                Kings Plaza           1
# 6   2       King's Al Ahmed Town           1
# 7   1            King's Comforts           1
#
#                                          description  country_id  \
# 0  Index Industrial Park is located in North West...           1
# 1  Kings Scenic Mall is the first and only Centra...           1
# 2  With 150, 166, 200, 266, and 400 sq. yd. resid...           1
# 3  A gateway to a lifestyle, you have been lookin...           1
# 4  Kings Regency is offering 3, 4, and 5-bedroom ...           1
# 5  A 4-story building with 2,3, and 4-room apartm...           1
# 6  120 sq. yd. and 200 sq. yd. plots, as well as ...           1
# ...

# %%
temp_data.to_csv('properties.csv',index=False)

# %% [markdown]
# # Airlines Data

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.instantwebtools.net/v1/airlines')
response
# Out:
# <Response [200]>

# %%
temp_data= pd.DataFrame(response.json())[['id','name','country','slogan','head_quaters','website','established']]
temp_data
# Out:
#                 id                name    country  \
# 0              1.0      Quatar Airways     Quatar
# 1              2.0  Singapore Airlines  Singapore
# 2              3.0      Cathay Pacific  Hong Kong
# 3              4.0            Emirates      Dubai
# 4              5.0             Eva Air     Taiwan
# ...            ...                 ...        ...
# 21676  281429976.0      Indian AirLine      India
# 21677  974140823.0      Indian AirLine      India
# 21678  615397936.0      Indian AirLine      India
# 21679  131218630.0      Indian AirLine      India
# 21680  297482425.0      Indian AirLine      India
#
#                                              slogan  \
# 0                             Going Places Together
# 1                                A Great Way to Fly
# 2                                       Move Beyond
# 3      From Dubai to destinations around the world.
# 4                Sharing the World, Flying Together
# ...

# %%
temp_data.shape
# Out:
# (21681, 7)

# %%
temp_data.to_csv('Airlines_data.csv',index=False)

# %%
temp_data[temp_data.isnull()]
# Out:
#        id name country slogan head_quaters website established
# 0     NaN  NaN     NaN    NaN          NaN     NaN         NaN
# 1     NaN  NaN     NaN    NaN          NaN     NaN         NaN
# 2     NaN  NaN     NaN    NaN          NaN     NaN         NaN
# 3     NaN  NaN     NaN    NaN          NaN     NaN         NaN
# 4     NaN  NaN     NaN    NaN          NaN     NaN         NaN
# ...    ..  ...     ...    ...          ...     ...         ...
# 21676 NaN  NaN     NaN    NaN          NaN     NaN         NaN
# 21677 NaN  NaN     NaN    NaN          NaN     NaN         NaN
# 21678 NaN  NaN     NaN    NaN          NaN     NaN         NaN
# 21679 NaN  NaN     NaN    NaN          NaN     NaN         NaN
# 21680 NaN  NaN     NaN    NaN          NaN     NaN         NaN
#
# [21681 rows x 7 columns]

# %%
temp_data.dropna(inplace=True)

# %%
Airline_clean_data = temp_data

# %%
Airline_clean_data
# Out:
#                 id                name    country  \
# 0              1.0      Quatar Airways     Quatar
# 1              2.0  Singapore Airlines  Singapore
# 2              3.0      Cathay Pacific  Hong Kong
# 3              4.0            Emirates      Dubai
# 4              5.0             Eva Air     Taiwan
# ...            ...                 ...        ...
# 21676  281429976.0      Indian AirLine      India
# 21677  974140823.0      Indian AirLine      India
# 21678  615397936.0      Indian AirLine      India
# 21679  131218630.0      Indian AirLine      India
# 21680  297482425.0      Indian AirLine      India
#
#                                              slogan  \
# 0                             Going Places Together
# 1                                A Great Way to Fly
# 2                                       Move Beyond
# 3      From Dubai to destinations around the world.
# 4                Sharing the World, Flying Together
# ...

# %%
Airline_clean_data.to_csv('Airline_data.csv',index=False)

# %% [markdown]
# # Bien' ici'

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://www.bienici.com/realEstateAds.json?filters=%7B%22size%22%3A24%2C%22from%22%3A0%2C%22showAllModels%22%3Afalse%2C%22filterType%22%3A%22buy%22%2C%22propertyType%22%3A%5B%22house%22%2C%22flat%22%5D%2C%22page%22%3A1%2C%22sortBy%22%3A%22relevance%22%2C%22sortOrder%22%3A%22desc%22%2C%22onTheMarket%22%3A%5Btrue%5D%2C%22limit%22%3A%22_jftH_gxP%3Fmwy%40~bCV%3F%7Cuy%40%22%2C%22newProperty%22%3Afalse%2C%22blurInfoType%22%3A%5B%22disk%22%2C%22exact%22%5D%2C%22zoneIdsByTypes%22%3A%7B%22zoneIds%22%3A%5B%22-58617%22%5D%7D%7D&extensionType=extendedIfNoResult&access_token=dtIrxP7GWLGlRFSSpkPc4mav43c9pJJz2IRjfCTtG30%3D%3A6422b4bd33c6fa00b6eb8822&id=6422b4bd33c6fa00b6eb8822')

# %%
response
# Out:
# <Response [200]>

# %%
temp_data = pd.DataFrame(response.json()['realEstateAds'])[['city','postalCode','propertyType','description']]

# %%
temp_data
# Out:
#             city postalCode propertyType  \
# 0   La Madeleine      59110         flat
# 1   La Madeleine      59110         flat
# 2   La Madeleine      59110         flat
# 3   La Madeleine      59110         flat
# 4   La Madeleine      59110         flat
# 5   La Madeleine      59110         flat
# 6   La Madeleine      59110         flat
# 7   La Madeleine      59110        house
# 8   La Madeleine      59110         flat
# 9   La Madeleine      59110         flat
# 10  La Madeleine      59110        house
# 11  La Madeleine      59110         flat
# 12  La Madeleine      59110         flat
# 13  La Madeleine      59110         flat
# 14  La Madeleine      59110         flat
# 15  La Madeleine      59110         flat
# 16  La Madeleine      59110         flat
# 17  La Madeleine      59110         flat
# 18  La Madeleine      59110        house
# 19  La Madeleine      59110         flat
# 20  La Madeleine      59110         flat
# 21  La Madeleine      59110         flat
# ...

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range (1,4):
    response = requests.get('https://www.bienici.com/realEstateAds.json?filters=%7B%22size%22%3A24%2C%22from%22%3A0%2C%22showAllModels%22%3Afalse%2C%22filterType%22%3A%22buy%22%2C%22propertyType%22%3A%5B%22house%22%2C%22flat%22%5D%2C%22page%22%3A1%2C%22sortBy%22%3A%22relevance%22%2C%22sortOrder%22%3A%22desc%22%2C%22onTheMarket%22%3A%5Btrue%5D%2C%22limit%22%3A%22_jftH_gxP%3Fmwy%40~bCV%3F%7Cuy%40%22%2C%22newProperty%22%3Afalse%2C%22blurInfoType%22%3A%5B%22disk%22%2C%22exact%22%5D%2C%22zoneIdsByTypes%22%3A%7B%22zoneIds%22%3A%5B%22-58617%22%5D%7D%7D&extensionType=extendedIfNoResult&access_token=dtIrxP7GWLGlRFSSpkPc4mav43c9pJJz2IRjfCTtG30%3D%3A6422b4bd33c6fa00b6eb8822&id=6422b4bd33c6fa00b6eb8822'.format(i))
    temp_data = pd.DataFrame(response.json()['realEstateAds'])[['city','postalCode','propertyType','description']]
    df = df.append(temp_data,ignore_index = True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_23964\11605579.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data,ignore_index = True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_23964\11605579.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data,ignore_index = True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_23964\11605579.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data,ignore_index = True)

# %%
df
# Out:
#             city postalCode propertyType  \
# 0   La Madeleine      59110         flat
# 1   La Madeleine      59110         flat
# 2   La Madeleine      59110         flat
# 3   La Madeleine      59110         flat
# 4   La Madeleine      59110         flat
# ..           ...        ...          ...
# 67  La Madeleine      59110         flat
# 68  La Madeleine      59110         flat
# 69  La Madeleine      59110         flat
# 70  La Madeleine      59110         flat
# 71  La Madeleine      59110        house
#
#                                           description
# 0   LA MADELEINE - Botanique  CENTURY 21 Apolite à...
# 1   Appartement T2 - LA MADELEINE - En exclusivité...
# 2   EXCLUSIVITÉ - QUARTIER GRAND BOULEVARD<br>À ve...
# 3   LA MADELEINE - Romarin  CENTURY 21 Apolite vou...
# 4   Dans le quartier du centre-ville, à la limite ...
# ..                                                ...
# 67  Au pied de l'arrêt de tramway Botanique, décou...
# ...

# %%
df.to_csv('peoperties.csv',index=False)

# %% [markdown]
# # Wallmart

# %%
import pandas as pd
import requests

# %%
response = requests.get("https://api.bluecartapi.com/request?api_key=demo&type=product&item_id=782866746")

# %%
pd.DataFrame(response.json())
# Out:
#                       request_info request_parameters  \
# success                       True                NaN
# demo                          True                NaN
# type                           NaN            product
# item_id                        NaN          782866746
# walmart_url                    NaN                NaN
# brand                          NaN                NaN
# manufacturer                   NaN                NaN
# link                           NaN                NaN
# title                          NaN                NaN
# upc                            NaN                NaN
# product_id                     NaN                NaN
# item_number                    NaN                NaN
# description                    NaN                NaN
# description_html               NaN                NaN
# description_full               NaN                NaN
# description_full_html          NaN                NaN
# ...
